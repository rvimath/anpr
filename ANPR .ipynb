# %% [markdown]
# ##  Install and Import Dependencies

# %%
# !pip install easyocr
# !pip install imutils
# !pip install opencv-python
# Out:
# Requirement already satisfied: easyocr in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (1.5.0)
# Requirement already satisfied: scipy in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (1.9.0)
# Requirement already satisfied: Pillow in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (9.1.1)
# Requirement already satisfied: scikit-image in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (0.19.3)
# Requirement already satisfied: torchvision>=0.5 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (0.13.1+cu113)
# Requirement already satisfied: PyYAML in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (6.0)
# Requirement already satisfied: numpy in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (1.23.1)
# Requirement already satisfied: python-bidi in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (0.4.2)
# Requirement already satisfied: torch in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (1.12.1+cu113)
# Requirement already satisfied: opencv-python-headless<=4.5.4.60 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from easyocr) (4.5.4.60)
# Requirement already satisfied: requests in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from torchvision>=0.5->easyocr) (2.28.1)
# Requirement already satisfied: typing-extensions in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from torchvision>=0.5->easyocr) (4.3.0)
# Requirement already satisfied: six in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from python-bidi->easyocr) (1.16.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (2022.8.12)
# Requirement already satisfied: PyWavelets>=1.1.1 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (1.3.0)
# Requirement already satisfied: imageio>=2.4.1 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (2.21.1)
# Requirement already satisfied: networkx>=2.2 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (2.8.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from scikit-image->easyocr) (21.3)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from packaging>=20.0->scikit-image->easyocr) (3.0.9)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2022.6.15)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from requests->torchvision>=0.5->easyocr) (1.26.10)
# Requirement already satisfied: imutils in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (0.5.4)
# Requirement already satisfied: opencv-python in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\vimat\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.23.1)

# %%
import cv2 #Image processing and Computer vison tasks
from matplotlib import pyplot as plt
import numpy as np
import imutils #Basic Image Processing
import easyocr #Extracting text from image

# %% [markdown]
# ## Read in Image, Grayscale and Blur

# %%
from PIL import Image #Python Pillow Library(Opening, Rotating, Disply images)

# %%
img = cv2.imread('img10.jpg') #Reading image using image module
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY) #Converting color image to Gray color 
plt.imshow(cv2.cvtColor(gray, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ##  Apply filter

# %%
bilateral_filter = cv2.bilateralFilter(gray, 15, 20, 20) #Noise reduction and blur image
plt.imshow(bilateral_filter)

# %% [markdown]
# #  Find edges for localization

# %%
edged = cv2.Canny(bilateral_filter, 170, 200) #Canny Edge detection
plt.imshow(cv2.cvtColor(edged, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Find Contours and Apply Mask

# %%
keypoints = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE) # Finding Boundaries of objects
contours = imutils.grab_contours(keypoints) #It does the basic image processing
contours = sorted(contours, key=cv2.contourArea, reverse=True)[:10]

# %%
location = None
for contour in contours:
    approx = cv2.approxPolyDP(contour, 10, True)#Approximate curve or Polygon
    if len(approx) == 4:
        location = approx
        break

# %%
location
# Out:
# array([[[118, 388]],
#
#        [[125, 419]],
#
#        [[278, 421]],
#
#        [[272, 388]]], dtype=int32)

# %%
mask = np.zeros(gray.shape, np.uint8)
new_image = cv2.drawContours(mask, [location], 0,255, -1)
new_image = cv2.bitwise_and(img, img, mask=mask) # Conjuntions of 2 array images

# %%
plt.imshow(cv2.cvtColor(new_image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# # Cropping Image

# %%
(x,y) = np.where(mask==255)
(x1, y1) = (np.min(x), np.min(y))
(x2, y2) = (np.max(x), np.max(y))
cropped_image = gray[x1:x2+1, y1:y2+1]

# %%
plt.imshow(cv2.cvtColor(cropped_image, cv2.COLOR_BGR2RGB))

# %% [markdown]
# ## Use Easy OCR To Read Text

# %%
reader = easyocr.Reader(['en'])
# reader = easyocr.Reader(['en'], detection='DB', recognition = 'Transformer')
result = reader.readtext(cropped_image)
result #1st Bounding box co ordinates, 2nd Extracted Text, 3rd Text prediction confidence
# Out:
# CUDA not available - defaulting to CPU. Note: This module is much faster with a GPU.
# [([[9, 0], [153, 0], [153, 34], [9, 34]], 'YXSS FFT', 0.7502055702256102)]

# %%
num = result[0][1].replace(" ", "") #Removing the Spaces from the Result

char1 = num[0:1] #1st character
char2 = num[1:2] #2nd character
char3 = num[2:3] #3rd character
char4 = num[3:4] #4th character
char5 = num[4:5] #5th character
char6 = num[5:6] #6th character
char7 = num[6:7] #7th character

if char3.upper() == "O":
    char3 = "0"
if char3 == "I" or char3 == "L":
    char3 = "1"
if char3.upper() == "S":
    char3 = "5"
if char3 == "B":
    char3 = "8"
if char3 == "G":
    char3 = "9"
if char3 == "b":
    char3 = "6"
if char3.upper() == "Z":
    char3 = "7"
    
if char4 == "O":
    char4 = "0"
if char4 == "S":
    char4 = "5"
if char4 == "G":
    char4 = "9"
if char4 == "B":
    char4 = "8"
if char4 == "b":
    char4 = "6"
if char4 == "I" or char4 == "L":
    char4 = "1"
if char4.upper() == "Z":
    char4 = "7"
    
text = (char1+char2+char3+char4+char5+char6+char7).upper() #Concatenate all the characters with uppercase
text
# Out:
# 'YX55FFT'

# %% [markdown]
# ##  Render Result

# %%
# text = result[0][1]
font = cv2.FONT_HERSHEY_SIMPLEX #Font
# Font Style, Thickness, Font color green
res = cv2.putText(img, text=text, org=(approx[0][0][0], approx[1][0][1]+60), fontFace=font, fontScale=1, color=(0,255,0), thickness=2, lineType=cv2.LINE_AA)
# Image where Rectangle is to be drawn, Starting point coordinates, Ending point coordinates, Green color, Thickness
res = cv2.rectangle(img, tuple(approx[0][0]), tuple(approx[2][0]), (0,255,0),3)
plt.imshow(cv2.cvtColor(res, cv2.COLOR_BGR2RGB))

# %%
print(text)
# Out:
# YX55FFT

# %% [markdown]
# ##  Saving the Extracted text in txt file

# %%
file = open("extraction.txt", "w")

# %%
# print(result[0][1].readlines())

# %%
file.write(text)
file.close()
